# %%
#LETS GROW MORE INTERNSHIP
#BEGINNER LEVEL TASK¶
#TASK 4 - IMAGE TO PENCIL SKETCH USING PYTHON

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread(r"/content/drive/MyDrive/RAM JI.jpeg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=766x891 at 0x7F4CF37C5710>

# %%
#Converting the original image to greyscale

# %%
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=766x891 at 0x7F4CE4099CD0>

# %%
#Inverting the greyscale image

# %%
inverted_image = 255 - grey_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=766x891 at 0x7F4CE3FB2750>

# %%
#Blurring the image by using the Gaussian Function in OpenCV

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=766x891 at 0x7F4CE3F32950>

# %%
#PENCIL SKETCH

# %%
def pencil_sketch(a, b):
  return cv2.divide(a, 255 - b, scale=256)
pencil_sketch=pencil_sketch(grey_image,blurred)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=766x891 at 0x7F4CE3F29C10>

# %%
#ORIGINAL IMAGE AND PENCIL SKETCH

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=766x891 at 0x7F4CE3F34E10>
# <PIL.Image.Image image mode=L size=766x891 at 0x7F4CE3F34350>

# %%
#TASK COMPLETED 
#THANKS AND REGARDS TANUJ
